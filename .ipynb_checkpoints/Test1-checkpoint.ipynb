# %%
import torch
import pandas as pd
import torch.nn as nn

# %%
user1 = pd.read_csv('../Data/User01_201508040439/Data.csv')

user1.head()
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                1.049744                7.471314                6.194779
# 1                1.091599                7.432984                6.143006
# 2                1.049530                7.436737                6.229782
# 3                0.996979                7.470124                6.245178
# 4                1.022980                7.486450                6.230042
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  GYROSCOPE X (rad/s)  \
# 0          1.052475          7.502223          6.227307             0.006348
# 1          1.056357          7.502919          6.225810             0.013824
# 2          1.058971          7.502639          6.225703             0.010620
# 3          1.059309          7.502846          6.225396            -0.002197
# 4          1.059312          7.502569          6.225730             0.003143
#
#    GYROSCOPE Y (rad/s)  GYROSCOPE Z (rad/s)  MAGNETIC FIELD X (μT)  \
# 0            -0.024078            -0.001297               -25.2132
# 1            -0.019806            -0.000229               -25.2783
# 2            -0.009125             0.011520               -25.9287
# 3            -0.000580             0.006180               -25.7986
# 4            -0.010193            -0.007706               -25.7771
#
#    MAGNETIC FIELD Y (μT)  MAGNETIC FIELD Z (μT)  ORIENTATION Z (azimuth °)  \
# 0                -8.8963               -17.0132                    64.9121
# 1                -8.8312               -17.0763                    64.9121
# 2                -8.9613               -17.7092                    64.9121
# 3                -8.7444               -18.1732                    63.8181
# 4                -8.7227               -18.2364                    63.8181
#
#    ORIENTATION X (pitch °)  ORIENTATION Y (roll °)  Time since start in ms   \
# 0                 -49.9082                 -9.5929                        6
# 1                 -49.9082                 -9.5929                       26
# 2                 -49.9082                 -9.5929                       47
# 3                 -49.9139                 -9.6569                       66
# 4                 -49.9139                 -9.6569                       87
#
#    YYYY-MO-DD HH-MI-SS_SSS
# 0  2015-08-04 04:39:35:907
# 1  2015-08-04 04:39:35:927
# 2  2015-08-04 04:39:35:948
# 3  2015-08-04 04:39:35:967
# 4  2015-08-04 04:39:35:988

# %%
user1.drop(user1.columns[[3, 4, 5, 6, 7, 8, 15, 16]], axis=1, inplace=True)

user1.head()
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                1.049744                7.471314                6.194779
# 1                1.091599                7.432984                6.143006
# 2                1.049530                7.436737                6.229782
# 3                0.996979                7.470124                6.245178
# 4                1.022980                7.486450                6.230042
#
#    MAGNETIC FIELD X (μT)  MAGNETIC FIELD Y (μT)  MAGNETIC FIELD Z (μT)  \
# 0               -25.2132                -8.8963               -17.0132
# 1               -25.2783                -8.8312               -17.0763
# 2               -25.9287                -8.9613               -17.7092
# 3               -25.7986                -8.7444               -18.1732
# 4               -25.7771                -8.7227               -18.2364
#
#    ORIENTATION Z (azimuth °)  ORIENTATION X (pitch °)  ORIENTATION Y (roll °)
# 0                    64.9121                 -49.9082                 -9.5929
# 1                    64.9121                 -49.9082                 -9.5929
# 2                    64.9121                 -49.9082                 -9.5929
# 3                    63.8181                 -49.9139                 -9.6569
# 4                    63.8181                 -49.9139                 -9.6569

# %%
cols = user1.columns.tolist()

print(cols)
# Out:
# ['ACCELEROMETER X (m/s²)', 'ACCELEROMETER Y (m/s²)', 'ACCELEROMETER Z (m/s²)', 'MAGNETIC FIELD X (μT)', 'MAGNETIC FIELD Y (μT)', 'MAGNETIC FIELD Z (μT)', 'ORIENTATION Z (azimuth °)', 'ORIENTATION X (pitch °)', 'ORIENTATION Y (roll °)']

# %%
user1 = user1[['ACCELEROMETER X (m/s²)', 'ACCELEROMETER Y (m/s²)', 'ACCELEROMETER Z (m/s²)', 'MAGNETIC FIELD X (μT)', 'MAGNETIC FIELD Y (μT)', 'MAGNETIC FIELD Z (μT)', 'ORIENTATION X (pitch °)', 'ORIENTATION Y (roll °)', 'ORIENTATION Z (azimuth °)']]

user1.head()
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                1.049744                7.471314                6.194779
# 1                1.091599                7.432984                6.143006
# 2                1.049530                7.436737                6.229782
# 3                0.996979                7.470124                6.245178
# 4                1.022980                7.486450                6.230042
#
#    MAGNETIC FIELD X (μT)  MAGNETIC FIELD Y (μT)  MAGNETIC FIELD Z (μT)  \
# 0               -25.2132                -8.8963               -17.0132
# 1               -25.2783                -8.8312               -17.0763
# 2               -25.9287                -8.9613               -17.7092
# 3               -25.7986                -8.7444               -18.1732
# 4               -25.7771                -8.7227               -18.2364
#
#    ORIENTATION X (pitch °)  ORIENTATION Y (roll °)  ORIENTATION Z (azimuth °)
# 0                 -49.9082                 -9.5929                    64.9121
# 1                 -49.9082                 -9.5929                    64.9121
# 2                 -49.9082                 -9.5929                    64.9121
# 3                 -49.9139                 -9.6569                    63.8181
# 4                 -49.9139                 -9.6569                    63.8181

# %%
user1Vals = user1.values

userTensor1 = user1Vals
X1 = userTensor1[:, :6]
y1 = userTensor1[:, 6:]
